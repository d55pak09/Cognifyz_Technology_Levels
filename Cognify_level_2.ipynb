# %% [markdown]
# ![Screenshot%20%28397%29-2.png](attachment:Screenshot%20%28397%29-2.png)

# %% [markdown]
# # Intern : Deepak Prajapat

# %% [markdown]
# ## Level 2  (Task 1,2,3,4)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset
df = pd.read_csv('Restaurent.csv')

# make a copy of data
data=df.copy()
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# ## Explore Data

# %%
# show sample of data
data.sample(5)
# Out:
#       Restaurant ID   Restaurant Name  Country Code       City  \
# 3223         302655   Arabian Delites             1  New Delhi
# 3525       18453878    Brainfreezzers             1  New Delhi
# 6366       18336477      Chilli Tadka             1  New Delhi
# 555        17697386  Galleria de Paco           216   Waterloo
# 4542           2295  Aroma Rest O Bar             1  New Delhi
#
#                                                 Address          Locality  \
# 3223      23, Flyover Market, Defence Colony, New Delhi    Defence Colony
# 3525  23/21-C, 1st Floor, Main Market, East Patel Na...  East Patel Nagar
# 6366  G-1, Ashish Complex, New Rajdhani Enclave, Pre...       Preet Vihar
# 555           622 Commercial Street, Waterloo, IA 50701          Waterloo
# 4542  18, Ashish Corporate Tower, Karkardooma Commun...       Karkardooma
#
#                  Locality Verbose  Longitude   Latitude  \
# 3223    Defence Colony, New Delhi  77.238122  28.577648
# ...

# %%
# showing information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# round the columns till two decimal places
data = round(data,2)
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# #### Numeric Columns

# %%
numeric_data = data.select_dtypes(include=['int','float'])
numeric_data
# Out:
#       Restaurant ID  Country Code  Longitude  Latitude  Average Cost for two  \
# 0           6317637           162     121.03     14.57                  1100
# 1           6304287           162     121.01     14.55                  1200
# 2           6300002           162     121.06     14.58                  4000
# 3           6318506           162     121.06     14.59                  1500
# 4           6314302           162     121.06     14.58                  1500
# ...             ...           ...        ...       ...                   ...
# 9546        5915730           208      28.98     41.02                    80
# 9547        5908749           208      29.04     41.01                   105
# 9548        5915807           208      29.03     41.06                   170
# 9549        5916112           208      29.04     41.06                   120
# 9550        5927402           208      29.03     40.98                    55
#
#       Price range  Aggregate rating  Votes
# ...

# %% [markdown]
# #### Categorical Columns

# %%
# showing categorical columns

categorical_cols = data.select_dtypes(include='object').head(5)
categorical_cols
# Out:
#           Restaurant Name              City  \
# 0        Le Petit Souffle       Makati City
# 1        Izakaya Kikufuji       Makati City
# 2  Heat - Edsa Shangri-La  Mandaluyong City
# 3                    Ooma  Mandaluyong City
# 4             Sambo Kojin  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose  \
# ...

# %%
categorical_cols['Restaurant Name'].unique()
# Out:
# array(['Le Petit Souffle', 'Izakaya Kikufuji', 'Heat - Edsa Shangri-La',
#        'Ooma', 'Sambo Kojin'], dtype=object)

# %% [markdown]
# ## Handling missing values

# %%
from sklearn.impute import SimpleImputer

# filling missing values
impute = SimpleImputer(strategy='most_frequent')
data[['Cuisines']] = impute.fit_transform(data[['Cuisines']])

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ![Screenshot%20%28410%29.png](attachment:Screenshot%20%28410%29.png)

# %% [markdown]
# #### Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
# The distribution of aggregate ratings
distribution_of_aggregate_ratings = df['Aggregate rating'].describe().to_frame()
distribution_of_aggregate_ratings
# Out:
#        Aggregate rating
# count       9551.000000
# mean           2.666370
# std            1.516378
# min            0.000000
# 25%            2.500000
# 50%            3.200000
# 75%            3.700000
# max            4.900000

# %%
# Top most 3 common rating range.
df['Aggregate rating'].value_counts().head(3).to_frame()
# Out:
#      Aggregate rating
# 0.0              2148
# 3.2               522
# 3.1               519

# %% [markdown]
# #### Calculate the average number of votes received by restaurants.

# %%
#  the average number of votes received by restaurants
df['Votes'].mean()
# Out:
# 156.909747670401

# %% [markdown]
# ![Screenshot%20%28411%29.png](attachment:Screenshot%20%28411%29.png)

# %% [markdown]
# #### Identify the most common combinations of cuisines in the dataset.

# %%
#1 the most common cuisines in the dataset.
cuisines_count = data['Cuisines'].value_counts()

# top 10 cuisines 
top_cuisines = cuisines_count.head(10)
print(top_cuisines,'\n')

print(' Top 3 cuisines combination')
print(' North Indian, Chinese','\n','North Indian, Mughlai','\n','North Indian, Mughlai, Chinese')
# Out:
# North Indian                      945
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64
#
#  Top 3 cuisines combination
#  North Indian, Chinese
#  North Indian, Mughlai
#  North Indian, Mughlai, Chinese

# %% [markdown]
# #### Determine if certain cuisine combinations tend to have higher ratings

# %%
# combine the necessary columns cuisines and rating text
df['cuisine combinations '] = df['Cuisines']+' '+ df['Rating text']

df['cuisine combinations '].value_counts().head(10)
# Out:
# North Indian Not rated                    444
# North Indian Average                      366
# North Indian, Chinese Average             303
# North Indian, Mughlai Average             185
# Chinese Average                           151
# Fast Food Average                         151
# Cafe Average                              132
# Chinese Not rated                         130
# Fast Food Not rated                       126
# North Indian, Mughlai, Chinese Average    122
# Name: cuisine combinations , dtype: int64

# %%
# Top three cuisines combination with average rating

# North Indian, Chinese Average 
# North Indian, Mughlai Average
# North Indian, Mughlai, Chinese Average

# %% [markdown]
# ![Screenshot%20%28412%29.png](attachment:Screenshot%20%28412%29.png)

# %% [markdown]
# #### Plot the locations of restaurants on a map using longitude and latitude coordinates.

# %%
import folium
import pandas as pd

# Load your dataset
# data = pd.read_csv('restaurant_data.csv')  # Replace 'restaurant_data.csv' with your actual file name

# Create a map centered at the mean latitude and longitude
center_lat = df['Latitude'].mean()
center_lng = df['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lng], zoom_start=10)

# Add markers for each restaurant
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Restaurant Name']).add_to(m)

# Save the map to an HTML file
m.save('restaurant_map.html')

# %% [markdown]
# #### Identify any patterns or clusters of restaurants in specific areas.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler



# Prepare the data for clustering
X = df[['Latitude', 'Longitude']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform K-Means clustering
num_clusters = 5  # You can adjust the number of clusters as needed
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
df['cluster'] = kmeans.fit_predict(X_scaled)

# Create a map centered at the mean latitude and longitude
center_lat = df['Latitude'].mean()
center_lng = df['Longitude'].mean()
m = folium.Map(location=[center_lat, center_lng], zoom_start=10)

# Assign different colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers for each restaurant with cluster color
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']],
                  popup=row['Restaurant Name'],
                  icon=folium.Icon(color=cluster_colors[row['cluster']])).add_to(m)

# Save the map to an HTML file
m.save('clustered_restaurant_map.html')
# Out:
# C:\Users\deepak parajapt\Downloads\New folder\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ![Screenshot%20%28413%29.png](attachment:Screenshot%20%28413%29.png)

# %% [markdown]
# #### Identify if there are any restaurant chains present in the dataset.

# %%
# Group restaurants by their name and count occurrences
restaurant_counts = df['Restaurant Name'].value_counts()

# Filter for restaurants with more than one occurrence (potential chains)
restaurant_chains = restaurant_counts[restaurant_counts > 1]

# Display the potential restaurant chains
print("Potential restaurant chains:")
print(restaurant_chains)
# Out:
# Potential restaurant chains:
# Cafe Coffee Day       83
# Domino's Pizza        79
# Subway                63
# Green Chick Chop      51
# McDonald's            48
#                       ..
# Town Hall              2
# Halki Aanch            2
# Snack Junction         2
# Delhi Biryani Hut      2
# Beliram Degchiwala     2
# Name: Restaurant Name, Length: 734, dtype: int64

# %% [markdown]
# #### Analyze the ratings and popularity of different restaurant chains.

# %%
 # Group restaurants by their name and count occurrences
df['new_rating'] = df['Restaurant Name'] +' '+ df['Rating text']

rating_var = df['new_rating'].value_counts()

# Filter for restaurants with rating text more than one occurrence (potential chains)
rating_var = rating_var[rating_var > 1]

# Display the potential rating_var
print("ratings of different restaurant chains:")
print(rating_var)


# the most commen rating is average of different restaurants chains
# Out:
# ratings of different restaurant chains:
# Cafe Coffee Day Average             59
# Domino's Pizza Average              53
# Subway Average                      43
# Green Chick Chop Average            40
# McDonald's Average                  27
#                                     ..
# Baked Buns Good                      2
# Shri Ram Restaurant Average          2
# Aggarwal Sweet Corner Average        2
# Nando's Good                         2
# Chawla Family Restaurant Average     2
# Name: new_rating, Length: 585, dtype: int64
